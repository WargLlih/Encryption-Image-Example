# %% [markdown]
# # Criptografando imagens

# %%
# * dependencias necessárias *
# numpy, matplotlib, opencv-python

#!pip install numpy matplotlib opencv-python

# %%
from random import randint
from time import time
import numpy as np
from matplotlib import pyplot as plt
import cv2

# %%
# !cat src/criptografia.py
# Out:
# from random import randint
# from time import time
# import numpy as np
# from matplotlib import pyplot as plt
# import cv2
#
#
#
# #======================== INPUT IMAGE ========================
# def input_img(image_name: str):
#   # Retorna as dimencoes da imagem e um objeto que é a sua imagem(img)
#   image = cv2.imread(image_name)
#   print("Dimensões da imagem: " + str(image.shape))
#   altura, largura, canais = image.shape
#   print(f'Largura: {largura}')
#   print(f'Altura: {altura}')
#   print(f'Canais de cores: {canais}')
#   return image, altura, largura, canais
#
#
#
# #======================== SHOW IMAGE ========================
# def show_image(image):
#   # Mostra Uma imagem
#   plt.figure(figsize = (5, 5))
#   plt.imshow(image)
#   plt.show()
#
#
#
# #======================== IMAGE BUILDER ========================
# def image_builder(altura: int, largura: int, canais: int, intarray: list):
#   # Retorna uma imagem com o conteudo intarray
# ...

# %%
from src.criptografia import input_img
from src.criptografia import show_image
from src.criptografia import image_builder
from src.criptografia import criptografar

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Entrando com a imagem
# #### uma senha é gerada com o mesmo tamanho da stream de bits da imagem

# %%
image_name = 'imagens/ada.jpg'#input('Nome da imagem com extensão: ') # entrando com a imagem
image, altura, largura, canais = input_img(image_name) # carregando a imagem e pegando suas dimensões
show_image(image) # mostrando a imagem
# Out:
# Dimensões da imagem: (1200, 1200, 3)
# Largura: 1200
# Altura: 1200
# Canais de cores: 3

# %% [markdown]
# ---------------------

# %% [markdown]
# ### Operação AND

# %%
ENC = criptografar(image, altura, largura, canais,'AND') # ENC é uma stream de bits

AND_IMAGE = image_builder(altura, largura, canais, ENC)
show_image(AND_IMAGE)
# Out:
# Tempo de criptografia: 8.578795433044434 sec

# %% [markdown]
# -------------------------------

# %% [markdown]
# ### Operação OR

# %%
ENC = criptografar(image, altura, largura, canais,'OR') # ENC é uma stream de bits

OR_IMAGE = image_builder(altura, largura, canais, ENC)
show_image(OR_IMAGE)
# Out:
# Tempo de criptografia: 8.659936428070068 sec

# %% [markdown]
# ------------------

# %% [markdown]
# ### Operação XOR

# %%
ENC = criptografar(image, altura, largura, canais,'XOR') # ENC é uma stream de bits

XOR_IMAGE = image_builder(altura, largura, canais, ENC)
show_image(XOR_IMAGE)
# Out:
# Tempo de criptografia: 8.86208176612854 sec
